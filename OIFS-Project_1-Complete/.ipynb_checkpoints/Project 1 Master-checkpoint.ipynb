# %%
#dependencies
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
# Names of CSV files
# https://www.washingtonpost.com/graphics/2018/national/police-shootings-2018/?utm_term=.00d1b94c6b6c

file = "fatal-police-shootings-data.csv"
file2 = "004-Crime and Gun Statistics.csv"

# %%
# Import Officer Involved Shootings CSV
ois = pd.read_csv(file)
ois.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  1/2/2015              shot         gun  53.0
# 1   4    Lewis Lee Lembke  1/2/2015              shot         gun  47.0
# 2   5  John Paul Quintero  1/3/2015  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  1/4/2015              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  1/4/2015              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
# remove columns
del ois['id']
del ois['manner_of_death']

#clean data of blankx#clean  
ois_clean = ois.dropna(how='any')
ois_clean.count()
# Out:
# name                       3000
# date                       3000
# armed                      3000
# age                        3000
# gender                     3000
# race                       3000
# city                       3000
# state                      3000
# signs_of_mental_illness    3000
# threat_level               3000
# flee                       3000
# body_camera                3000
# dtype: int64

# %%
#find types of armed 
ois_clean["gender"].value_counts()
# Out:
# M    2865
# F     135
# Name: gender, dtype: int64

# %%
ois_clean["armed"].unique()
# Out:
# array(['gun', 'unarmed', 'toy weapon', 'nail gun', 'knife', 'vehicle',
#        'shovel', 'hammer', 'hatchet', 'undetermined', 'sword', 'machete',
#        'box cutter', 'metal object', 'screwdriver', 'lawn mower blade',
#        'flagpole', 'guns and explosives', 'cordless drill', 'metal pole',
#        'Taser', 'metal pipe', 'metal hand tool', 'blunt object',
#        'metal stick', 'sharp object', 'meat cleaver', 'carjack', 'chain',
#        "contractor's level", 'unknown weapon', 'stapler', 'crossbow',
#        'bean-bag gun', 'baseball bat and fireplace poker',
#        'straight edge razor', 'gun and knife', 'ax', 'brick',
#        'baseball bat', 'hand torch', 'chain saw', 'garden tool',
#        'scissors', 'pole', 'pick-axe', 'flashlight', 'spear', 'chair',
#        'pitchfork', 'hatchet and gun', 'rock', 'piece of wood', 'bayonet',
#        'glass shard', 'motorcycle', 'pepper spray', 'metal rake', 'baton',
#        'crowbar', 'oar', 'machete and gun', 'air conditioner',
#        'pole and knife', 'beer bottle', 'pipe', 'baseball bat and bottle',
#        'fireworks', 'pen', 'chainsaw', 'gun and sword', 'gun and car',
#        'pellet gun', 'BB gun', 'incendiary device'], dtype=object)

# %%
# consolidate list of weapons in incidents located in "armed" column
ois_clean["armed"] = ois_clean["armed"].replace(
    { 'nail gun': 'other',
       'shovel': 'other', 'hammer': 'other', 'hatchet': 'other', 'sword': 'other',
       'box cutter': 'other', 'metal object': 'other', 'screwdriver': 'other', 'lawn mower blade': 'other',
       'flagpole': 'other', 'guns and explosives': 'other', 'cordless drill': 'other', 'metal pole': 'other',
       'Taser': 'other', 'metal pipe': 'other', 'metal hand tool': 'other', 'blunt object': 'other',
       'metal stick': 'other', 'sharp object': 'other', 'meat cleaver': 'knife', 'carjack': 'other', 'chain': 'other',
       "contractor's level": 'other', 'stapler': 'other', 'crossbow': 'other',
       'bean-bag gun': 'gun', 'baseball bat and fireplace poker': 'other',
       'straight edge razor': 'knife', 'gun and knife': 'other', 'ax': 'other', 'brick': 'other',
       'baseball bat': 'other', 'hand torch': 'other', 'chain saw': 'other', 'garden tool': 'other',
       'scissors': 'knife', 'pole': 'other', 'pick-axe': 'other', 'flashlight': 'other', 'spear': 'other', 'chair': 'other',
       'pitchfork': 'other', 'hatchet and gun': 'other', 'rock': 'other', 'piece of wood': 'other', 'bayonet': 'knife',
       'glass shard': 'other', 'motorcycle': 'vehicle', 'pepper spray': 'other', 'metal rake': 'other', 'baton': 'other',
       'crowbar': 'other', 'oar': 'other', 'machete and gun': 'other', 'air conditioner': 'other',
       'pole and knife': 'other', 'beer bottle': 'other', 'pipe': 'other', 'baseball bat and bottle': 'other',
       'fireworks': 'other', 'pen': 'other', 'chainsaw': 'other', 'gun and sword': 'other', 'gun and car': 'other',
       'pellet gun': 'gun', 'BB gun': 'gun', 'incendiary device': 'other', 'machete': 'knife', 'unknown weapon': 'other',
        'undetermined': 'other'})
ois_clean["armed"].value_counts()
# Out:
# C:\Users\astor\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# gun           1678
# knife          463
# other          298
# unarmed        232
# vehicle        211
# toy weapon     118
# Name: armed, dtype: int64

# %%
#output clean CSV
ois_clean.to_csv("ois_clean.csv")

# %%
#state abbeviations dictionary
state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
# import clean csv
wapo=pd.read_csv("ois_clean.csv")
wapo.head()
# Out:
#    Unnamed: 0                name      date       armed   age gender race  \
# 0           0          Tim Elliot  1/2/2015         gun  53.0      M    A
# 1           1    Lewis Lee Lembke  1/2/2015         gun  47.0      M    W
# 2           2  John Paul Quintero  1/3/2015     unarmed  23.0      M    H
# 3           3     Matthew Hoffman  1/4/2015  toy weapon  32.0      M    W
# 4           4   Michael Rodriguez  1/4/2015       other  39.0      M    H
#
#             city state  signs_of_mental_illness threat_level         flee  \
# 0        Shelton    WA                     True       attack  Not fleeing
# 1          Aloha    OR                    False       attack  Not fleeing
# 2        Wichita    KS                    False        other  Not fleeing
# 3  San Francisco    CA                     True       attack  Not fleeing
# 4          Evans    CO                    False       attack  Not fleeing
#
#    body_camera
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# import csv of US census regions/divisions from:
# (https://github.com/cphalpert/census-regions/blob/master/us%20census%20bureau%20regions%20and%20divisions.csv)
regions=pd.read_csv("us census bureau regions and divisions.csv")
regions=regions.drop(regions.index[7])
regions=regions.drop(columns="State")
regions=regions.rename(columns={"State Code": "State"})
regions
# Out:
#    State     Region            Division
# 0     AK       West             Pacific
# 1     AL      South  East South Central
# 2     AR      South  West South Central
# 3     AZ       West            Mountain
# 4     CA       West             Pacific
# 5     CO       West            Mountain
# 6     CT  Northeast         New England
# 8     DE      South      South Atlantic
# 9     FL      South      South Atlantic
# 10    GA      South      South Atlantic
# 11    HI       West             Pacific
# 12    IA    Midwest  West North Central
# 13    ID       West            Mountain
# 14    IL    Midwest  East North Central
# 15    IN    Midwest  East North Central
# 16    KS    Midwest  West North Central
# 17    KY      South  East South Central
# 18    LA      South  West South Central
# 19    MA  Northeast         New England
# 20    MD      South      South Atlantic
# 21    ME  Northeast         New England
# 22    MI    Midwest  East North Central
# 23    MN    Midwest  West North Central
# 24    MO    Midwest  West North Central
# 25    MS      South  East South Central
# 26    MT       West            Mountain
# 27    NC      South      South Atlantic
# 28    ND    Midwest  West North Central
# 29    NE    Midwest  West North Central
# 30    NH  Northeast         New England
# 31    NJ  Northeast     Middle Atlantic
# 32    NM       West            Mountain
# 33    NV       West            Mountain
# 34    NY  Northeast     Middle Atlantic
# 35    OH    Midwest  East North Central
# 36    OK      South  West South Central
# 37    OR       West             Pacific
# 38    PA  Northeast     Middle Atlantic
# 39    RI  Northeast         New England
# 40    SC      South      South Atlantic
# 41    SD    Midwest  West North Central
# 42    TN      South  East South Central
# 43    TX      South  West South Central
# 44    UT       West            Mountain
# 45    VA      South      South Atlantic
# 46    VT  Northeast         New England
# 47    WA       West             Pacific
# 48    WI    Midwest  East North Central
# 49    WV      South      South Atlantic
# 50    WY       West            Mountain

# %%
# create dataframe of incidents per state
armed_df=wapo[["state", "armed"]]
armed_df=armed_df.rename(columns={"state":"State", "armed":"Armed"})
state_counts=armed_df.groupby("State").count()
state_counts=state_counts.reset_index(drop=False)

state_counts.head()
# Out:
#   State  Armed
# 0    AK     19
# 1    AL     63
# 2    AR     31
# 3    AZ    143
# 4    CA    463

# %%
# create dataframe of incidents by deceased armed vs. unarmed and weapons involved
weapon_counts=armed_df.groupby("Armed").count()
weapon_counts=weapon_counts.reset_index(drop=False)
weapon_counts=weapon_counts.rename(columns={"State":"Incidents"})
weapon_counts
# Out:
#         Armed  Incidents
# 0         gun       1678
# 1       knife        463
# 2       other        298
# 3  toy weapon        118
# 4     unarmed        232
# 5     vehicle        211

# %%
# create pie chart of deceased civilian weapons
labels=weapon_counts["Armed"]
explode=(0,0,0,0,0.3,0)
plt.pie(weapon_counts["Incidents"], startangle=90, labels=labels, explode=explode, autopct = "%1.1f%%", shadow=True)
plt.title("Weapons Possessed by Deceased")
plt.axis("Equal")
# plt.figure(figsize=(20,20))
plt.savefig("weapons.png")

# %%
# api call for population below poverty level by state
from config import api_key
url = "https://api.census.gov/data/2016/acs/acs1?get=NAME,B01003_001E,B17001_002E&for=state:*&key="
query_url= url + api_key
census_data = requests.get(query_url).json()

# %%
# create dataframe from api data o poverty, drop header, D.C. and Puerto Rico
poverty_df = pd.DataFrame(census_data, columns= ["State Name", "Estimated Population", "Below Poverty Level", "State ID"])
poverty_df=poverty_df.drop(poverty_df.index[[0, 9, 52]])
poverty_df=poverty_df.reset_index(drop=True)
poverty_df.head()
# Out:
#    State Name Estimated Population Below Poverty Level State ID
# 0     Alabama              4863300              810231       01
# 1      Alaska               741894               71566       02
# 2     Arizona              6931071             1107464       04
# 3    Arkansas              2988248              499225       05
# 4  California             39250017             5525524       06

# %%
# convert objects to integers
poverty_df["Est Pop"] = poverty_df["Estimated Population"].astype("int") 
poverty_df["Below Poverty Level"] = poverty_df["Below Poverty Level"].astype("int") 
# convert total to percent
poverty_df["% Below Poverty Level"]=poverty_df["Below Poverty Level"] / poverty_df["Est Pop"] * 100
# Map state full names to abbreviations
poverty_df["State"]=poverty_df["State Name"].map(state_abbrev)
poverty_df=poverty_df[["State", "% Below Poverty Level", "Est Pop"]]

merged_poverty=pd.merge(poverty_df, state_counts, how="inner", on="State")
merged_poverty=merged_poverty.rename(columns={"Armed":"Incidents"})
merged_poverty["Incidents Per 100k People"]=merged_poverty["Incidents"] / (merged_poverty["Est Pop"] / 100000)
merged_poverty=pd.merge(merged_poverty, regions, how="inner", on="State")
merged_poverty
# Out:
#    State  % Below Poverty Level   Est Pop  Incidents  \
# 0     AL              16.660107   4863300         63
# 1     AK               9.646392    741894         19
# 2     AZ              15.978252   6931071        143
# 3     AR              16.706277   2988248         31
# 4     CA              14.077762  39250017        463
# 5     CO              10.806446   5540545         90
# 6     CT               9.482247   3576452         10
# 7     DE              11.365926    952065          9
# 8     FL              14.425813  20612439        189
# 9     GA              15.547578  10310371         90
# 10    HI               9.069922   1428557         11
# 11    ID              14.107264   1683140         23
# 12    IL              12.666508  12801539         71
# 13    IN              13.660030   6633053         57
# 14    IA              11.368833   3134693         16
# 15    KS              11.782248   2907289         33
# 16    KY              17.896431   4436974         59
# 17    LA              19.612399   4681666         62
# 18    ME              12.148070   1331479         10
# 19    MD               9.436051   6016447         42
# 20    MA              10.079555   6811779         25
# 21    MI              14.624216   9928300         53
# 22    MN               9.660881   5519952         39
# 23    MS              20.168058   2988726         36
# 24    MO              13.572198   6093000         78
# 25    MT              13.010590   1042520         16
# 26    NE              11.087579   1907116         14
# 27    NV              13.585446   2940058         47
# 28    NH               7.063931   1334795          7
# 29    NJ              10.239993   8944469         36
# 30    NM              19.435852   2081015         60
# 31    NY              14.346835  19745289         54
# 32    NC              14.998638  10146788         89
# 33    ND              10.352093    757953          7
# 34    OH              14.166774  11614373         95
# 35    OK              15.811580   3923561         87
# 36    OR              13.097608   4093465         42
# 37    PA              12.453197  12784227         65
# 38    RI              12.299205   1056426          3
# 39    SC              14.834556   4961119         51
# 40    SD              12.821248    865454         10
# 41    TN              15.383358   6651194         68
# 42    TX              15.294113  27862596        250
# 43    UT              10.058347   3051217         31
# 44    VT              11.420058    624594          6
# 45    VA              10.656924   8411808         64
# 46    WA              11.055036   7288000         72
# 47    WV              17.424644   1831102         28
# 48    WI              11.448318   5778709         55
# 49    WY              11.044046    585501         10
#
#     Incidents Per 100k People     Region            Division
# 0                    1.295417      South  East South Central
# 1                    2.561013       West             Pacific
# 2                    2.063173       West            Mountain
# 3                    1.037397      South  West South Central
# 4                    1.179617       West             Pacific
# 5                    1.624389       West            Mountain
# 6                    0.279607  Northeast         New England
# 7                    0.945314      South      South Atlantic
# 8                    0.916922      South      South Atlantic
# 9                    0.872907      South      South Atlantic
# 10                   0.770008       West             Pacific
# 11                   1.366494       West            Mountain
# 12                   0.554621    Midwest  East North Central
# 13                   0.859333    Midwest  East North Central
# 14                   0.510417    Midwest  West North Central
# 15                   1.135078    Midwest  West North Central
# 16                   1.329735      South  East South Central
# 17                   1.324315      South  West South Central
# 18                   0.751045  Northeast         New England
# 19                   0.698086      South      South Atlantic
# 20                   0.367011  Northeast         New England
# 21                   0.533828    Midwest  East North Central
# 22                   0.706528    Midwest  West North Central
# 23                   1.204527      South  East South Central
# 24                   1.280158    Midwest  West North Central
# 25                   1.534743       West            Mountain
# 26                   0.734093    Midwest  West North Central
# 27                   1.598608       West            Mountain
# 28                   0.524425  Northeast         New England
# 29                   0.402483  Northeast     Middle Atlantic
# 30                   2.883208       West            Mountain
# 31                   0.273483  Northeast     Middle Atlantic
# 32                   0.877125      South      South Atlantic
# 33                   0.923540    Midwest  West North Central
# 34                   0.817952    Midwest  East North Central
# 35                   2.217373      South  West South Central
# 36                   1.026026       West             Pacific
# 37                   0.508439  Northeast     Middle Atlantic
# 38                   0.283976  Northeast         New England
# 39                   1.027994      South      South Atlantic
# 40                   1.155463    Midwest  West North Central
# 41                   1.022373      South  East South Central
# 42                   0.897260      South  West South Central
# 43                   1.015988       West            Mountain
# 44                   0.960624  Northeast         New England
# 45                   0.760835      South      South Atlantic
# 46                   0.987925       West             Pacific
# 47                   1.529134      South      South Atlantic
# 48                   0.951770    Midwest  East North Central
# 49                   1.707939       West            Mountain

# %%
sns.lmplot( x="Incidents Per 100k People", y="% Below Poverty Level", data=merged_poverty, fit_reg=False, hue="Region", legend=False)
plt.title("Incidents Per State vs. % of State Below Poverty Level, By Region")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("povlevel-region.png", bbox_inches="tight")

# %%
sns.lmplot( x="Incidents Per 100k People", y="% Below Poverty Level", data=merged_poverty, fit_reg=False, hue="Division", legend=False)
plt.title("Incidents Per State vs. % of State Below Poverty Level, By Regional Division")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.savefig("povlevel-division.png", bbox_inches="tight")

# %%
sns.regplot(x="Incidents Per 100k People", y="% Below Poverty Level", data=merged_poverty)
plt.title("Incidents Per State vs. % of State Below Poverty Level")
plt.savefig("povlevel-regression.png", bbox_inches="tight")

# %%
# api call from census for population by race listed per state
race_criteria="B01003_001E,B03002_003E,B03002_004E,B03002_005E,B03002_006E,B03002_007E,B03002_008E,B03002_009E,B03002_012E,B03002_002E"
race_url = f"https://api.census.gov/data/2016/acs/acs1?get=NAME,{race_criteria}&for=state:*&key="
race_query= race_url + api_key
race_data = requests.get(race_query).json()

# %%
race_df = pd.DataFrame(race_data, columns= ["State Name","Total Population","White alone","Black or African American alone",
                                            "American Indian and Alaska Native alone","Asian alone",
                                            "Native Hawaiian and Other Pacific Islander alone","Some other race alone",
                                            "Two or more races","Hispanic or Latino","Not Hispanic or Latino","State ID"])


race_df=race_df.drop(race_df.index[[0,9,52]])
race_df=race_df.reset_index(drop=True)
race_df
# Out:
#         State Name Total Population White alone  \
# 0          Alabama          4863300     3197147
# 1           Alaska           741894      452757
# 2          Arizona          6931071     3834724
# 3         Arkansas          2988248     2175226
# 4       California         39250017    14725729
# 5         Colorado          5540545     3796733
# 6      Connecticut          3576452     2411769
# 7         Delaware           952065      597331
# 8          Florida         20612439    11271384
# 9          Georgia         10310371     5484889
# 10          Hawaii          1428557      315242
# 11           Idaho          1683140     1385885
# 12        Illinois         12801539     7886677
# 13         Indiana          6633053     5273458
# 14            Iowa          3134693     2708501
# 15          Kansas          2907289     2216482
# 16        Kentucky          4436974     3765752
# 17       Louisiana          4681666     2754601
# 18           Maine          1331479     1243607
# 19        Maryland          6016447     3092525
# 20   Massachusetts          6811779     4928862
# 21        Michigan          9928300     7474930
# 22       Minnesota          5519952     4444184
# 23     Mississippi          2988726     1698241
# 24        Missouri          6093000     4852074
# 25         Montana          1042520      900884
# 26        Nebraska          1907116     1519945
# 27          Nevada          2940058     1463596
# 28   New Hampshire          1334795     1211076
# 29      New Jersey          8944469     4966755
# 30      New Mexico          2081015      787250
# 31        New York         19745289    10962313
# 32  North Carolina         10146788     6438334
# 33    North Dakota           757953      644710
# 34            Ohio         11614373     9216496
# 35        Oklahoma          3923561     2595562
# 36          Oregon          4093465     3119464
# 37    Pennsylvania         12784227     9832127
# 38    Rhode Island          1056426      768815
# 39  South Carolina          4961119     3161469
# 40    South Dakota           865454      713315
# 41       Tennessee          6651194     4929450
# 42           Texas         27862596    11843864
# 43            Utah          3051217     2401230
# 44         Vermont           624594      580616
# 45        Virginia          8411808     5235564
# 46      Washington          7288000     5053546
# 47   West Virginia          1831102     1684936
# 48       Wisconsin          5778709     4718160
# 49         Wyoming           585501      494078
#
#    Black or African American alone American Indian and Alaska Native alone  \
# 0                          1294572                                   21225
# 1                            21768                                  104362
# 2                           284478                                  274472
# 3                           462232                                   16096
# 4                          2160958                                  132153
# 5                           220728                                   28993
# 6                           352345                                    4968
# 7                           203278                                    3281
# 8                          3162469                                   38654
# 9                          3205543                                   17417
# 10                           24389                                    1718
# 11                           10184                                   21522
# 12                         1790654                                   15415
# 13                          608667                                   13870
# 14                          108502                                    8662
# 15                          161027                                   18397
# 16                          360428                                   10692
# 17                         1502898                                   24319
# 18                           17963                                    7130
# 19                         1765641                                   12217
# 20                          456681                                    8154
# 21                         1347079                                   42919
# 22                          325256                                   57795
# 23                         1131449                                   12939
# 24                          698734                                   27492
# 25                            3439                                   62998
# 26                           87110                                   13963
# 27                          249544                                   26593
# 28                           15837                                    1336
# 29                         1130491                                    8810
# 30                           37782                                  178176
# 31                         2829419                                   45228
# 32                         2144650                                  108345
# 33                           18815                                   40676
# 34                         1421393                                   15138
# 35                          281976                                  283500
# 36                           75516                                   36097
# 37                         1351705                                   13312
# 38                           58523                                    2913
# 39                         1328097                                   13805
# 40                           14332                                   73570
# 41                         1105799                                   15049
# 42                         3270776                                   67038
# 43                           30915                                   26769
# 44                            7307                                    2113
# 45                         1575478                                   19718
# 46                          254841                                   79382
# 47                           68738                                    3734
# 48                          355473                                   48653
# 49                            5400                                   12328
#
#    Asian alone Native Hawaiian and Other Pacific Islander alone  \
# 0        65100                                             1341
# 1        44235                                             9766
# 2       214132                                            12834
# 3        41387                                             8808
# 4      5518226                                           137019
# 5       173588                                             7397
# 6       159838                                              505
# 7        35591                                              990
# 8       550606                                            10290
# 9       396429                                             5134
# 10      527847                                           131672
# 11       22993                                             1910
# 12      679106                                             3126
# 13      140694                                             2786
# 14       74554                                             3700
# 15       79100                                             2922
# 16       60837                                             1934
# 17       77518                                              562
# 18       17499                                              214
# 19      374779                                             2101
# 20      438614                                             3006
# 21      291323                                             2462
# 22      257673                                             1255
# 23       26685                                              631
# 24      116024                                             7521
# 25        8326                                              547
# 26       41133                                             1200
# 27      240323                                            18016
# 28       32455                                               66
# 29      849117                                             2840
# 30       30149                                             1077
# 31     1654883                                             6491
# 32      273281                                             5376
# 33        9111                                              233
# 34      237401                                             3218
# 35       78185                                             5717
# 36      167053                                            13830
# 37      420202                                             2446
# 38       36176                                             1237
# 39       75511                                             2179
# 40       12901                                              151
# 41      115106                                             4732
# 42     1281698                                            20254
# 43       69181                                            28870
# 44        9406                                              252
# 45      527900                                             6769
# 46      591025                                            46683
# 47       13777                                              404
# 48      154748                                              987
# 49        5815                                              173
#
#    Some other race alone Two or more races Hispanic or Latino  \
# 0                   7537             76692             199686
# 1                   1741             55961              51304
# 2                  10072            155584            2144775
# 3                   2917             67038             214544
# 4                 105389           1189767           15280776
# 5                   6313            125575            1181218
# 6                  11451             73229             562347
# 7                   1419             23023              87152
# 8                  70928            381530            5126578
# 9                  32116            206509             962334
# 10                  1852            277687             148150
# 11                   702             32696             207248
# 12                 18718            229053            2178790
# 13                 10478            135021             448079
# 14                  2784             48928             179062
# 15                  3221             89231             336909
# 16                  7172             78239             151920
# 17                  7665             82935             231168
# 18                   900             23452              20714
# 19                 15752            166702             586730
# 20                 59495            137271             779696
# 21                 15319            262838             491430
# 22                  7324            138005             288460
# 23                  2529             29519              86733
# 24                 10479            137109             243567
# 25                   574             28662              37090
# 26                  1719             39597             202449
# 27                  6566             98794             836626
# 28                  1645             25109              47271
# 29                 40991            158796            1786669
# 30                  4299             32406            1009876
# 31                106193            393148            3747614
# 32                 19620            226072             931110
# 33                   127             17847              26434
# 34                 19951            280695             420081
# 35                  4059            270626             403936
# 36                  5961            152976             522568
# 37                 19352            245081             900002
# 38                  6210             25200             157352
# 39                 12827             94440             272791
# 40                   280             18678              32227
# 41                  8919            124697             347442
# 42                 38404            457283           10883279
# 43                  3070             70742             420440
# 44                   727             11627              12546
# 45                 23107            262661             760611
# 46                 10670            345402             906451
# 47                  3361             29369              26783
# 48                  3230            110443             387015
# 49                   211             11232              56264
#
#    Not Hispanic or Latino State ID
# 0                 4663614       01
# 1                  690590       02
# 2                 4786296       04
# 3                 2773704       05
# 4                23969241       06
# 5                 4359327       08
# 6                 3014105       09
# 7                  864913       10
# 8                15485861       12
# 9                 9348037       13
# 10                1280407       15
# 11                1475892       16
# 12               10622749       17
# 13                6184974       18
# 14                2955631       19
# 15                2570380       20
# 16                4285054       21
# 17                4450498       22
# 18                1310765       23
# 19                5429717       24
# 20                6032083       25
# 21                9436870       26
# 22                5231492       27
# 23                2901993       28
# 24                5849433       29
# 25                1005430       30
# 26                1704667       31
# 27                2103432       32
# 28                1287524       33
# 29                7157800       34
# 30                1071139       35
# 31               15997675       36
# 32                9215678       37
# 33                 731519       38
# 34               11194292       39
# 35                3519625       40
# 36                3570897       41
# 37               11884225       42
# 38                 899074       44
# 39                4688328       45
# 40                 833227       46
# 41                6303752       47
# 42               16979317       48
# 43                2630777       49
# 44                 612048       50
# 45                7651197       51
# 46                6381549       53
# 47                1804319       54
# 48                5391694       55
# 49                 529237       56

# %%
total_criteria="B01003_001E,B03002_003E,B03002_004E,B03002_005E,B03002_006E,B03002_007E,B03002_008E,B03002_009E,B03002_012E,B03002_002E"
total_race_url = f"https://api.census.gov/data/2016/acs/acs1?get={total_criteria}&for=US:1&key="
total_query= total_race_url + api_key
total_data = requests.get(total_query).json()

total_df = pd.DataFrame(total_data, columns= ["Total Population","White alone","Black or African American alone",
                                            "American Indian and Alaska Native alone","Asian alone",
                                            "Native Hawaiian and Other Pacific Islander alone","Some other race alone",
                                            "Two or more races","Hispanic or Latino","Not Hispanic or Latino", "Index"])


total_df=total_df.drop(race_df.index[[0]])
del total_df["Total Population"]
del total_df["Index"]
del total_df["Two or more races"]
del total_df["Not Hispanic or Latino"]

total_df["White alone"] = total_df["White alone"].astype("float")
total_df["Black or African American alone"] = total_df["Black or African American alone"].astype("int")
total_df["American Indian and Alaska Native alone"] = total_df["American Indian and Alaska Native alone"].astype("int")
total_df["Asian alone"] = total_df["Asian alone"].astype("int")
total_df["Native Hawaiian and Other Pacific Islander alone"] = total_df["Native Hawaiian and Other Pacific Islander alone"].astype("int")
total_df["Hispanic or Latino"] = total_df["Hispanic or Latino"].astype("int")
total_df["Some other race alone"] = total_df["Some other race alone"].astype("int")
total_df["Other"]=total_df["Native Hawaiian and Other Pacific Islander alone"] + total_df["Some other race alone"]

del total_df["Native Hawaiian and Other Pacific Islander alone"]
del total_df["Some other race alone"]

total_df=total_df.stack()
total_df
# Out:
# 1  White alone                                197479450.0
#    Black or African American alone             39717127.0
#    American Indian and Alaska Native alone      2125635.0
#    Asian alone                                 17345193.0
#    Hispanic or Latino                          57398719.0
#    Other                                        1291950.0
# dtype: float64

# %%
# calculate diversity index as defined by UNC and USA Today: https://www.unc.edu/~pmeyer/carstat/tools.html

#convert objects to integers
race_df["TP"] = race_df["Total Population"].astype("int")
race_df["W"] = race_df["White alone"].astype("int")
race_df["B"] = race_df["Black or African American alone"].astype("int")
race_df["AI"] = race_df["American Indian and Alaska Native alone"].astype("int")
race_df["A"] = race_df["Asian alone"].astype("int")
race_df["PI"] = race_df["Native Hawaiian and Other Pacific Islander alone"].astype("int")
race_df["H"] = race_df["Hispanic or Latino"].astype("int")
race_df["NH"] = race_df["Not Hispanic or Latino"].astype("int")

diversity_index=[]
for index, row in race_df.iterrows():
    # convert totals to percentage of total pop
    row["W"]=row["W"]/row["TP"]
    row["B"]=row["B"]/row["TP"]
    row["AI"]=row["AI"]/row["TP"]
    row["A"]=row["A"]/row["TP"]
    row["PI"]=row["PI"]/row["TP"]
    row["H"]=row["H"]/row["TP"]
    row["NH"]=row["NH"]/row["TP"]
    #calculate index
    diversity_calc = (1-((row["W"]**2 + row["B"]**2 + row["AI"]**2 + row["A"]**2 + row["PI"]**2) * 
                          (row["H"]**2 + row ["NH"]**2))) * 100
    
    diversity_index.append(diversity_calc)

diversity_df=pd.DataFrame({"State":merged_poverty["State"],"Diversity":diversity_index, "Incidents/100k":merged_poverty["Incidents Per 100k People"]})
diversity_df["Diversity"]=diversity_df["Diversity"].round(3)

diversity_df.head()
# Out:
#    Diversity  Incidents/100k State
# 0     53.639        1.295417    AL
# 1     65.428        2.561013    AK
# 2     82.231        2.063173    AZ
# 3     51.981        1.037397    AR
# 4     91.420        1.179617    CA

# %%
plt.scatter(diversity_df["Incidents/100k"], diversity_df["Diversity"])
plt.xlabel("Incidents Per 100k people")
plt.ylabel("Diversity Index of State")
# Out:
# Text(0,0.5,'Diversity Index of State')

# %%
sns.regplot(x="Incidents/100k", y="Diversity", data=diversity_df)
plt.xlabel("Incidents Per 100k people")
plt.ylabel("Diversity Index of State")
plt.title("Incidents Per 100k People vs. Diversity Index of State")
plt.savefig("divindex-regression.png", bbox_inches="tight")

# %%
gun_stats = pd.read_csv(file2)
gun_stats.head()
# Out:
#    State Name  Gun Murder Rate per 100K (2010) Gun Ownership (2007)  \
# 0     Alabama                              2.8               51.70%
# 1      Alaska                              2.7               57.80%
# 2     Arizona                              3.6               31.10%
# 3    Arkansas                              3.2               55.30%
# 4  California                              3.4               21.30%
#
#    Violent Crime  (per 100,000) 2013  \
# 0                              449.9
# 1                              603.2
# 2                              428.9
# 3                              469.1
# 4                              423.1
#
#    Murder and nonnegligent manslaughter (per 100K) 2013  \
# 0                                                7.1
# 1                                                4.1
# 2                                                5.5
# 3                                                5.9
# 4                                                5.0
#
#    Forcible rape (per 100K) 2013  Robbery (per 100K) 2013  \
# 0                           26.9                    104.1
# 1                           79.7                     86.1
# 2                           34.7                    112.7
# 3                           42.3                     78.7
# 4                           20.6                    148.6
#
#    Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                311.8                           3502.2
# 1                                433.2                           2739.4
# 2                                276.0                           3539.2
# 3                                342.3                           3660.1
# 4                                248.9                           2758.7
#
#    Burglary  (per 100K) 2013  Larceny (per 100K) 2013  \
# 0                      984.7                   2312.8
# 1                      403.3                   2128.0
# 2                      807.8                   2439.1
# 3                     1081.3                   2384.7
# 4                      646.1                   1669.5
#
#    Motor Theft (per 100K) 2013
# 0                        204.8
# 1                        208.1
# 2                        292.3
# 3                        194.1
# 4                        443.2

# %%
#gun_stats=gun_stats['Gun Ownership (2007)'].astype('float')#gun_st 
gun_stats["Gun Ownership (2007)"] = gun_stats["Gun Ownership (2007)"].replace({'\%':''}, regex = True)
gun_stats.head()
# Out:
#    State Name  Gun Murder Rate per 100K (2010) Gun Ownership (2007)  \
# 0     Alabama                              2.8                51.70
# 1      Alaska                              2.7                57.80
# 2     Arizona                              3.6                31.10
# 3    Arkansas                              3.2                55.30
# 4  California                              3.4                21.30
#
#    Violent Crime  (per 100,000) 2013  \
# 0                              449.9
# 1                              603.2
# 2                              428.9
# 3                              469.1
# 4                              423.1
#
#    Murder and nonnegligent manslaughter (per 100K) 2013  \
# 0                                                7.1
# 1                                                4.1
# 2                                                5.5
# 3                                                5.9
# 4                                                5.0
#
#    Forcible rape (per 100K) 2013  Robbery (per 100K) 2013  \
# 0                           26.9                    104.1
# 1                           79.7                     86.1
# 2                           34.7                    112.7
# 3                           42.3                     78.7
# 4                           20.6                    148.6
#
#    Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                311.8                           3502.2
# 1                                433.2                           2739.4
# 2                                276.0                           3539.2
# 3                                342.3                           3660.1
# 4                                248.9                           2758.7
#
#    Burglary  (per 100K) 2013  Larceny (per 100K) 2013  \
# 0                      984.7                   2312.8
# 1                      403.3                   2128.0
# 2                      807.8                   2439.1
# 3                     1081.3                   2384.7
# 4                      646.1                   1669.5
#
#    Motor Theft (per 100K) 2013
# 0                        204.8
# 1                        208.1
# 2                        292.3
# 3                        194.1
# 4                        443.2

# %%
gun= gun_stats.rename(columns={"Gun Ownership (2007)":"Gun Ownership",'Violent Crime  (per 100,000) 2013':"Violent Crime" })
gun.head(50)
# Out:
#               State Name  Gun Murder Rate per 100K (2010) Gun Ownership  \
# 0                Alabama                              2.8         51.70
# 1                 Alaska                              2.7         57.80
# 2                Arizona                              3.6         31.10
# 3               Arkansas                              3.2         55.30
# 4             California                              3.4         21.30
# 5               Colorado                              1.3         34.70
# 6            Connecticut                              2.7         16.70
# 7               Delaware                              4.2         25.50
# 8   District of Columbia                             16.5          3.60
# 9                Florida                              3.9         24.50
# 10               Georgia                              3.8         40.30
# 11                Hawaii                              0.5          6.70
# 12                 Idaho                              0.8         55.30
# 13              Illinois                              2.8         20.20
# 14               Indiana                              2.2         39.10
# 15                  Iowa                              0.7         42.90
# 16                Kansas                              2.2         42.10
# 17              Kentucky                              2.7         47.70
# 18             Louisiana                              7.7         44.10
# 19                 Maine                              0.8         40.50
# 20              Maryland                              5.1         21.30
# 21         Massachusetts                              1.8         12.60
# 22              Michigan                              4.2         38.40
# 23             Minnesota                              1.0         41.70
# 24           Mississippi                              4.0         55.30
# 25              Missouri                              5.4         41.70
# 26               Montana                              1.2         57.70
# 27              Nebraska                              1.8         38.60
# 28                Nevada                              3.1         33.80
# 29         New Hampshire                              0.4         30.00
# 30            New Jersey                              2.8         12.30
# 31            New Mexico                              3.3         34.80
# 32              New York                              2.7         18.00
# 33        North Carolina                              3.0         41.30
# 34          North Dakota                              0.6         50.70
# 35                  Ohio                              2.7         32.40
# 36              Oklahoma                              3.0         42.90
# 37                Oregon                              0.9         39.80
# 38          Pennsylvania                              3.6         34.70
# 39          Rhode Island                              1.5         12.80
# 40        South Carolina                              4.5         42.30
# 41          South Dakota                              1.0         56.60
# 42             Tennessee                              3.5         43.90
# 43                 Texas                              3.2         35.90
# 44                  Utah                              0.8         43.90
# 45               Vermont                              0.3         42.00
# 46              Virginia                              3.1         35.10
# 47            Washington                              1.4         33.10
# 48         West Virginia                              1.5         55.40
# 49             Wisconsin                              1.7         44.40
#
#     Violent Crime  Murder and nonnegligent manslaughter (per 100K) 2013  \
# 0           449.9                                                7.1
# 1           603.2                                                4.1
# 2           428.9                                                5.5
# 3           469.1                                                5.9
# 4           423.1                                                5.0
# 5           308.9                                                3.1
# 6           283.0                                                4.1
# 7           547.4                                                6.2
# 8          1243.7                                               13.9
# 9           487.1                                                5.2
# 10          378.9                                                5.9
# 11          239.2                                                2.1
# 12          207.9                                                1.8
# 13          414.8                                                5.8
# 14          345.7                                                4.7
# 15          263.9                                                1.5
# 16          354.6                                                2.9
# 17          222.6                                                4.5
# 18          496.9                                               10.8
# 19          122.7                                                1.9
# 20          476.8                                                6.3
# 21          405.5                                                1.8
# 22          454.5                                                7.0
# 23          230.9                                                1.8
# 24          260.8                                                7.4
# 25          450.9                                                6.5
# 26          272.2                                                2.7
# 27          259.4                                                2.9
# 28          607.6                                                4.5
# 29          187.9                                                1.1
# 30          290.2                                                4.4
# 31          559.1                                                5.6
# 32          406.8                                                3.5
# 33          353.4                                                4.9
# 34          244.7                                                4.0
# 35          299.7                                                4.3
# 36          469.3                                                5.7
# 37          247.6                                                2.4
# 38          348.7                                                5.4
# 39          252.4                                                3.2
# 40          558.8                                                6.9
# 41          321.8                                                3.0
# 42          643.6                                                6.0
# 43          408.6                                                4.4
# 44          205.8                                                1.8
# 45          142.6                                                1.3
# 46          190.1                                                3.8
# 47          295.6                                                3.0
# 48          316.3                                                3.9
# 49          280.5                                                3.0
#
#     Forcible rape (per 100K) 2013  Robbery (per 100K) 2013  \
# 0                            26.9                    104.1
# 1                            79.7                     86.1
# 2                            34.7                    112.7
# 3                            42.3                     78.7
# 4                            20.6                    148.6
# 5                            40.7                     65.4
# 6                            25.6                    102.7
# 7                            26.5                    162.7
# 8                            37.3                    638.3
# 9                            27.2                    123.7
# 10                           21.4                    125.6
# 11                           20.5                     74.7
# 12                           30.0                     15.2
# 13                           27.7                    151.2
# 14                           25.5                    100.9
# 15                           28.3                     31.3
# 16                           36.5                     52.0
# 17                           29.0                     80.7
# 18                           25.2                    119.0
# 19                           28.0                     31.8
# 20                           21.0                    172.3
# 21                           24.7                     98.6
# 22                           46.4                    105.6
# 23                           30.5                     64.6
# 24                           27.5                     76.5
# 25                           25.1                     96.0
# 26                           37.7                     19.0
# 27                           38.3                     60.9
# 28                           33.7                    178.3
# 29                           34.0                     35.7
# 30                           11.7                    128.4
# 31                           45.9                     88.6
# 32                           14.6                    146.4
# 33                           20.3                     96.3
# 34                           38.9                     18.7
# 35                           31.7                    132.0
# 36                           41.6                     84.7
# 37                           29.2                     61.9
# 38                           26.1                    122.8
# 39                           27.4                     67.9
# 40                           35.5                     95.0
# 41                           70.2                     19.0
# 42                           31.5                    126.5
# 43                           29.6                    116.6
# 44                           33.0                     38.5
# 45                           19.3                     17.9
# 46                           17.7                     57.5
# 47                           31.8                     83.3
# 48                           22.7                     45.2
# 49                           21.3                     80.7
#
#     Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                 311.8                           3502.2
# 1                                 433.2                           2739.4
# 2                                 276.0                           3539.2
# 3                                 342.3                           3660.1
# 4                                 248.9                           2758.7
# 5                                 199.6                           2684.7
# 6                                 150.6                           2140.0
# 7                                 352.0                           3340.9
# 8                                 554.1                           4860.8
# 9                                 330.9                           3276.7
# 10                                226.0                           3410.6
# 11                                141.9                           3075.2
# 12                                160.9                           1983.5
# 13                                230.0                           2578.7
# 14                                214.6                           3029.2
# 15                                202.8                           2271.8
# 16                                263.2                           3143.2
# 17                                108.4                           2552.9
# 18                                342.0                           3540.6
# 19                                 61.0                           2509.9
# 20                                277.2                           2753.5
# 21                                280.4                           2153.0
# 22                                295.5                           2530.5
# 23                                134.0                           2568.3
# 24                                149.4                           2811.0
# 25                                323.4                           3314.4
# 26                                212.8                           2583.7
# 27                                157.4                           2754.9
# 28                                391.1                           2809.4
# 29                                117.0                           2324.0
# 30                                145.7                           2047.3
# 31                                419.1                           3600.7
# 32                                242.3                           1922.0
# 33                                231.8                           3369.5
# 34                                183.1                           2010.1
# 35                                131.7                           3117.4
# 36                                337.3                           3401.0
# 37                                154.1                           3224.2
# 38                                194.4                           2166.3
# 39                                153.9                           2572.3
# 40                                421.4                           3822.2
# 41                                229.7                           2060.1
# 42                                479.6                           3371.4
# 43                                258.0                           3361.8
# 44                                132.5                           2991.8
# 45                                104.2                           2398.7
# 46                                111.1                           2162.1
# 47                                177.5                           3658.6
# 48                                244.6                           2364.9
# 49                                175.5                           2453.8
#
#     Burglary  (per 100K) 2013  Larceny (per 100K) 2013  \
# 0                       984.7                   2312.8
# 1                       403.3                   2128.0
# 2                       807.8                   2439.1
# 3                      1081.3                   2384.7
# 4                       646.1                   1669.5
# 5                       504.2                   1947.4
# 6                       409.7                   1550.7
# 7                       803.7                   2380.6
# 8                       556.5                   3725.3
# 9                       794.9                   2288.6
# 10                      874.9                   2248.0
# 11                      573.1                   2243.2
# 12                      450.3                   1447.7
# 13                      552.2                   1826.9
# 14                      728.3                   2092.0
# 15                      556.1                   1584.8
# 16                      650.3                   2258.0
# 17                      675.4                   1725.2
# 18                      915.7                   2453.7
# 19                      561.3                   1873.7
# 20                      573.2                   1924.9
# 21                      519.7                   1494.4
# 22                      664.4                   1612.0
# 23                      471.8                   1939.3
# 24                      940.6                   1725.6
# 25                      705.2                   2338.4
# 26                      387.4                   2028.3
# 27                      470.8                   2060.7
# 28                      801.8                   1644.6
# 29                      412.2                   1834.3
# 30                      477.6                   1383.7
# 31                     1025.3                   2313.4
# 32                      329.9                   1503.5
# 33                     1018.5                   2185.7
# 34                      339.8                   1505.8
# 35                      895.9                   2052.5
# 36                      936.6                   2161.3
# 37                      561.7                   2400.9
# 38                      445.5                   1603.1
# 39                      566.4                   1755.7
# 40                      954.5                   2588.3
# 41                      391.0                   1541.4
# 42                      870.2                   2300.1
# 43                      785.9                   2326.4
# 44                      453.3                   2328.4
# 45                      633.4                   1695.8
# 46                      360.5                   1690.7
# 47                      880.5                   2395.3
# 48                      608.5                   1637.3
# 49                      488.0                   1822.3
#
#     Motor Theft (per 100K) 2013
# 0                         204.8
# 1                         208.1
# 2                         292.3
# 3                         194.1
# 4                         443.2
# 5                         233.1
# 6                         179.6
# 7                         156.6
# 8                         579.0
# 9                         193.2
# 10                        287.7
# 11                        258.9
# 12                         85.5
# 13                        199.5
# 14                        209.0
# 15                        130.9
# 16                        234.9
# 17                        152.2
# 18                        171.3
# 19                         74.9
# 20                        255.3
# 21                        138.9
# 22                        254.1
# 23                        157.2
# 24                        144.8
# 25                        270.8
# 26                        168.0
# 27                        223.5
# 28                        363.1
# 29                         77.5
# 30                        185.9
# 31                        261.9
# 32                         88.6
# 33                        165.3
# 34                        164.5
# 35                        169.0
# 36                        303.1
# 37                        261.7
# 38                        117.7
# 39                        250.2
# 40                        279.5
# 41                        127.8
# 42                        201.0
# 43                        249.4
# 44                        210.1
# 45                         69.5
# 46                        110.9
# 47                        382.8
# 48                        119.1
# 49                        143.5

# %%
gun['Gun Ownership'] = gun['Gun Ownership'].astype('float')

# %%
oisdata = pd.read_csv(file)
oisdata.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  1/2/2015              shot         gun  53.0
# 1   4    Lewis Lee Lembke  1/2/2015              shot         gun  47.0
# 2   5  John Paul Quintero  1/3/2015  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  1/4/2015              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  1/4/2015              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %%
gb_oisdata = oisdata.groupby("state").count()
gb_oisdata.head()
# Out:
#         id  name  date  manner_of_death  armed  age  gender  race  city  \
# state
# AK      22    22    22               22     22   22      22    19    22
# AL      73    73    73               73     73   69      73    64    73
# AR      40    40    40               40     40   40      40    33    40
# AZ     169   169   169              169    169  162     169   147   169
# CA     543   543   543              543    542  516     542   484   543
#
#        signs_of_mental_illness  threat_level  flee  body_camera
# state
# AK                          22            22    22           22
# AL                          73            73    72           73
# AR                          40            40    37           40
# AZ                         169           169   164          169
# CA                         543           543   530          543

# %%
np.corrcoef(gun['Violent Crime'], gb_oisdata['name'])
# Out:
# array([[1.       , 0.0770752],
#        [0.0770752, 1.       ]])

# %%
gun["State"]=gun["State Name"].map(state_abbrev)
gun.head()
# Out:
#    State Name  Gun Murder Rate per 100K (2010)  Gun Ownership  Violent Crime  \
# 0     Alabama                              2.8           51.7          449.9
# 1      Alaska                              2.7           57.8          603.2
# 2     Arizona                              3.6           31.1          428.9
# 3    Arkansas                              3.2           55.3          469.1
# 4  California                              3.4           21.3          423.1
#
#    Murder and nonnegligent manslaughter (per 100K) 2013  \
# 0                                                7.1
# 1                                                4.1
# 2                                                5.5
# 3                                                5.9
# 4                                                5.0
#
#    Forcible rape (per 100K) 2013  Robbery (per 100K) 2013  \
# 0                           26.9                    104.1
# 1                           79.7                     86.1
# 2                           34.7                    112.7
# 3                           42.3                     78.7
# 4                           20.6                    148.6
#
#    Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                311.8                           3502.2
# 1                                433.2                           2739.4
# 2                                276.0                           3539.2
# 3                                342.3                           3660.1
# 4                                248.9                           2758.7
#
#    Burglary  (per 100K) 2013  Larceny (per 100K) 2013  \
# 0                      984.7                   2312.8
# 1                      403.3                   2128.0
# 2                      807.8                   2439.1
# 3                     1081.3                   2384.7
# 4                      646.1                   1669.5
#
#    Motor Theft (per 100K) 2013 State
# 0                        204.8    AL
# 1                        208.1    AK
# 2                        292.3    AZ
# 3                        194.1    AR
# 4                        443.2    CA

# %%
new_merge=pd.merge(merged_poverty, gun, how="left", on="State")
new_merge.head()
# new_merge.to_csv("new merge.csv")
# Out:
#   State  % Below Poverty Level   Est Pop  Incidents  \
# 0    AL              16.660107   4863300         63
# 1    AK               9.646392    741894         19
# 2    AZ              15.978252   6931071        143
# 3    AR              16.706277   2988248         31
# 4    CA              14.077762  39250017        463
#
#    Incidents Per 100k People Region            Division  State Name  \
# 0                   1.295417  South  East South Central     Alabama
# 1                   2.561013   West             Pacific      Alaska
# 2                   2.063173   West            Mountain     Arizona
# 3                   1.037397  South  West South Central    Arkansas
# 4                   1.179617   West             Pacific  California
#
#    Gun Murder Rate per 100K (2010)  Gun Ownership  Violent Crime  \
# 0                              2.8           51.7          449.9
# 1                              2.7           57.8          603.2
# 2                              3.6           31.1          428.9
# 3                              3.2           55.3          469.1
# 4                              3.4           21.3          423.1
#
#    Murder and nonnegligent manslaughter (per 100K) 2013  \
# 0                                                7.1
# 1                                                4.1
# 2                                                5.5
# 3                                                5.9
# 4                                                5.0
#
#    Forcible rape (per 100K) 2013  Robbery (per 100K) 2013  \
# 0                           26.9                    104.1
# 1                           79.7                     86.1
# 2                           34.7                    112.7
# 3                           42.3                     78.7
# 4                           20.6                    148.6
#
#    Aggravated assault  (per 100K) 2013  Property Crime  (per 100K) 2013  \
# 0                                311.8                           3502.2
# 1                                433.2                           2739.4
# 2                                276.0                           3539.2
# 3                                342.3                           3660.1
# 4                                248.9                           2758.7
#
#    Burglary  (per 100K) 2013  Larceny (per 100K) 2013  \
# 0                      984.7                   2312.8
# 1                      403.3                   2128.0
# 2                      807.8                   2439.1
# 3                     1081.3                   2384.7
# 4                      646.1                   1669.5
#
#    Motor Theft (per 100K) 2013
# 0                        204.8
# 1                        208.1
# 2                        292.3
# 3                        194.1
# 4                        443.2

# %%
sns.lmplot(x="Incidents Per 100k People", y="Violent Crime", data=new_merge, fit_reg=False, hue="Region", legend=False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("Incidents Per 100k People vs. Violent Crime Per State, By Region")
plt.savefig("violent-region.png", bbox_inches="tight")

# %%
sns.lmplot(x="Incidents Per 100k People", y="Gun Ownership", data=new_merge, fit_reg=False, hue="Region", legend=False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title("Incidents Per 100k People vs. Gun Ownership Per State, By Region")
plt.savefig("gunowner-region.png", bbox_inches="tight")

# %%
sns.regplot(x="Incidents Per 100k People", y="Violent Crime", data=new_merge)
plt.title("Incidents Per 100k People vs. Violent Crime Per State")
plt.savefig("violent-regression.png", bbox_inches="tight")

# %%
sns.regplot(x="Incidents Per 100k People", y="Gun Ownership", data=new_merge)
plt.title("Incidents Per 100k People vs. Gun Ownership Per State")
plt.savefig("gunowner-regression.png", bbox_inches="tight")

# %%
race_keys = wapo["race"].value_counts().keys()
print(race_keys)
list(race_keys)
race_values = wapo["race"].value_counts().values
race_values
type(race_values)
# Out:
# Index(['W', 'B', 'H', 'N', 'A', 'O'], dtype='object')
# numpy.ndarray

# %%
# deceased by race

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
#
labels = ["White", "Black", "Hispanic", "Native American", "Asian", "Other"]
sizes = list(race_values)
piecolors=["red", "blue", "green", "gold", "cyan", "fuchsia"]
piecolors2=["red", "blue", "gold", "cyan", "green", "fuchsia"]

fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, colors=piecolors, autopct='%1.1f%%',
        shadow=True, startangle=0, pctdistance=.83)
    
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Shooting Victims by Race")
plt.savefig("incidents-race-pie.png")
plt.show()

# %%
# total population by race 
labels = ["White", "Black", "Native American", "Asian", "Hispanic", "Other"]

fig1, ax1 = plt.subplots()
ax1.pie(total_df, labels=labels, colors=piecolors2, autopct='%1.1f%%',
        shadow=True, startangle=90, pctdistance=.83)
    
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("US Population by Race")
plt.savefig("us-race-pie.png")
plt.show()

# %%
#read in csv
MedianIncome_df = pd.read_csv("StateMedianIncome.csv")
MedianIncome_df.head()
# Out:
#       GEO.id GEO.id2 GEO.display-label GCT_STUB.target-geo-id  \
# 0         Id     Id2         Geography          Target Geo Id
# 1  0100000US     NaN     United States              0100000US
# 2  0100000US     NaN     United States            0400000US01
# 3  0100000US     NaN     United States            0400000US02
# 4  0100000US     NaN     United States            0400000US04
#
#   GCT_STUB.target-geo-id2   GCT_STUB.display-label GCT_STUB.display-label.1  \
# 0          Target Geo Id2          Geographic Area          Geographic Area
# 1                     NaN            United States            United States
# 2                       1  United States - Alabama                  Alabama
# 3                       2   United States - Alaska                   Alaska
# 4                       4  United States - Arizona                  Arizona
#
#      HC01             HC02
# 0  Dollar  Margin of Error
# 1   67871              212
# 2   56828              414
# 3   87365             1180
# 4   61001              314

# %%
MedianIncome_df1 = MedianIncome_df[["GCT_STUB.display-label.1", "HC01", ]]
MedianIncome_df1.head(10)
# Out:
#   GCT_STUB.display-label.1    HC01
# 0          Geographic Area  Dollar
# 1            United States   67871
# 2                  Alabama   56828
# 3                   Alaska   87365
# 4                  Arizona   61001
# 5                 Arkansas   53123
# 6               California   72952
# 7                 Colorado   77130
# 8              Connecticut   91274
# 9                 Delaware   73831

# %%
CleanMedianIncome_df = MedianIncome_df1.rename(columns={"GCT_STUB.display-label.1": "State Name", "HC01": "Median Income"})
CleanMedianIncome_df.head(10)
# Out:
#         State Name Median Income
# 0  Geographic Area        Dollar
# 1    United States         67871
# 2          Alabama         56828
# 3           Alaska         87365
# 4          Arizona         61001
# 5         Arkansas         53123
# 6       California         72952
# 7         Colorado         77130
# 8      Connecticut         91274
# 9         Delaware         73831

# %%
CleanMedianIncome_df1 = CleanMedianIncome_df.drop(CleanMedianIncome_df.index[[0,1,10,53]])
CleanMedianIncome_df1
# Out:
#         State Name Median Income
# 2          Alabama         56828
# 3           Alaska         87365
# 4          Arizona         61001
# 5         Arkansas         53123
# 6       California         72952
# 7         Colorado         77130
# 8      Connecticut         91274
# 9         Delaware         73831
# 11         Florida         59139
# 12         Georgia         61328
# 13          Hawaii         83451
# 14           Idaho         59652
# 15        Illinois         73714
# 16         Indiana         62748
# 17            Iowa         69419
# 18          Kansas         68231
# 19        Kentucky         56522
# 20       Louisiana         58068
# 21           Maine         64294
# 22        Maryland         92049
# 23   Massachusetts         90180
# 24        Michigan         63958
# 25       Minnesota         79595
# 26     Mississippi         50592
# 27        Missouri         62285
# 28         Montana         63214
# 29        Nebraska         69207
# 30          Nevada         62528
# 31   New Hampshire         83709
# 32      New Jersey         90757
# 33      New Mexico         55900
# 34        New York         74036
# 35  North Carolina         59667
# 36    North Dakota         77277
# 37            Ohio         64433
# 38        Oklahoma         59742
# 39          Oregon         65479
# 40    Pennsylvania         69960
# 41    Rhode Island         75655
# 42  South Carolina         58158
# 43    South Dakota         66825
# 44       Tennessee         57747
# 45           Texas         64585
# 46            Utah         71058
# 47         Vermont         71465
# 48        Virginia         80068
# 49      Washington         76507
# 50   West Virginia         54409
# 51       Wisconsin         69925
# 52         Wyoming         73654

# %%
CleanMedianIncome_df1["State"]=CleanMedianIncome_df1["State Name"].map(state_abbrev)
CleanMedianIncome_df1
# Out:
#         State Name Median Income State
# 2          Alabama         56828    AL
# 3           Alaska         87365    AK
# 4          Arizona         61001    AZ
# 5         Arkansas         53123    AR
# 6       California         72952    CA
# 7         Colorado         77130    CO
# 8      Connecticut         91274    CT
# 9         Delaware         73831    DE
# 11         Florida         59139    FL
# 12         Georgia         61328    GA
# 13          Hawaii         83451    HI
# 14           Idaho         59652    ID
# 15        Illinois         73714    IL
# 16         Indiana         62748    IN
# 17            Iowa         69419    IA
# 18          Kansas         68231    KS
# 19        Kentucky         56522    KY
# 20       Louisiana         58068    LA
# 21           Maine         64294    ME
# 22        Maryland         92049    MD
# 23   Massachusetts         90180    MA
# 24        Michigan         63958    MI
# 25       Minnesota         79595    MN
# 26     Mississippi         50592    MS
# 27        Missouri         62285    MO
# 28         Montana         63214    MT
# 29        Nebraska         69207    NE
# 30          Nevada         62528    NV
# 31   New Hampshire         83709    NH
# 32      New Jersey         90757    NJ
# 33      New Mexico         55900    NM
# 34        New York         74036    NY
# 35  North Carolina         59667    NC
# 36    North Dakota         77277    ND
# 37            Ohio         64433    OH
# 38        Oklahoma         59742    OK
# 39          Oregon         65479    OR
# 40    Pennsylvania         69960    PA
# 41    Rhode Island         75655    RI
# 42  South Carolina         58158    SC
# 43    South Dakota         66825    SD
# 44       Tennessee         57747    TN
# 45           Texas         64585    TX
# 46            Utah         71058    UT
# 47         Vermont         71465    VT
# 48        Virginia         80068    VA
# 49      Washington         76507    WA
# 50   West Virginia         54409    WV
# 51       Wisconsin         69925    WI
# 52         Wyoming         73654    WY

# %%
income_merge=pd.merge(CleanMedianIncome_df1, merged_poverty, how="left", on="State")
income_merge.head()
# Out:
#    State Name Median Income State  % Below Poverty Level   Est Pop  Incidents  \
# 0     Alabama         56828    AL              16.660107   4863300         63
# 1      Alaska         87365    AK               9.646392    741894         19
# 2     Arizona         61001    AZ              15.978252   6931071        143
# 3    Arkansas         53123    AR              16.706277   2988248         31
# 4  California         72952    CA              14.077762  39250017        463
#
#    Incidents Per 100k People Region            Division
# 0                   1.295417  South  East South Central
# 1                   2.561013   West             Pacific
# 2                   2.063173   West            Mountain
# 3                   1.037397  South  West South Central
# 4                   1.179617   West             Pacific

# %%
income_merge["Median Income"]=income_merge["Median Income"].astype("int")

# %%
sns.regplot(x="Incidents Per 100k People", y="Median Income", data=income_merge)
plt.title("Incidents Per 100k People vs. Median Income of State")
plt.savefig("incidents-income-regression.png",  bbox_inches="tight")

# %%
#Import data 
csv_path = "ois_clean.csv" 
Officer_shootings_df = pd.read_csv(csv_path)
Officer_shootings_df.head()
# Out:
#    Unnamed: 0                name      date       armed   age gender race  \
# 0           0          Tim Elliot  1/2/2015         gun  53.0      M    A
# 1           1    Lewis Lee Lembke  1/2/2015         gun  47.0      M    W
# 2           2  John Paul Quintero  1/3/2015     unarmed  23.0      M    H
# 3           3     Matthew Hoffman  1/4/2015  toy weapon  32.0      M    W
# 4           4   Michael Rodriguez  1/4/2015       other  39.0      M    H
#
#             city state  signs_of_mental_illness threat_level         flee  \
# 0        Shelton    WA                     True       attack  Not fleeing
# 1          Aloha    OR                    False       attack  Not fleeing
# 2        Wichita    KS                    False        other  Not fleeing
# 3  San Francisco    CA                     True       attack  Not fleeing
# 4          Evans    CO                    False       attack  Not fleeing
#
#    body_camera
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
#create bins
age_bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 100]

#create group names
group_names = ["0-5", "5-10", "11-15","16-20", "21-25", "26-30", "31-35", "36-40", "41-45", "46-50", "51-55", "56-60", "61-65", "66-70", "71-75", "76-80", "Over 80"]

# %%
#drop in bins
Officer_shootings_df["age_range"]= pd.cut(Officer_shootings_df["age"], age_bins, labels=group_names)
Officer_shootings_df.head()
# Out:
#    Unnamed: 0                name      date       armed   age gender race  \
# 0           0          Tim Elliot  1/2/2015         gun  53.0      M    A
# 1           1    Lewis Lee Lembke  1/2/2015         gun  47.0      M    W
# 2           2  John Paul Quintero  1/3/2015     unarmed  23.0      M    H
# 3           3     Matthew Hoffman  1/4/2015  toy weapon  32.0      M    W
# 4           4   Michael Rodriguez  1/4/2015       other  39.0      M    H
#
#             city state  signs_of_mental_illness threat_level         flee  \
# 0        Shelton    WA                     True       attack  Not fleeing
# 1          Aloha    OR                    False       attack  Not fleeing
# 2        Wichita    KS                    False        other  Not fleeing
# 3  San Francisco    CA                     True       attack  Not fleeing
# 4          Evans    CO                    False       attack  Not fleeing
#
#    body_camera age_range
# 0        False     51-55
# 1        False     46-50
# 2        False     21-25
# 3        False     31-35
# 4        False     36-40

# %%
#group by age bins

Officer_shootings_df_bins = Officer_shootings_df.groupby("age_range")
#Officer_shootings_df_bins.head()
values = Officer_shootings_df_bins["age_range"].count()
values
# Out:
# age_range
# 0-5          0
# 5-10         1
# 11-15       15
# 16-20      205
# 21-25      441
# 26-30      474
# 31-35      494
# 36-40      383
# 41-45      289
# 46-50      243
# 51-55      184
# 56-60      133
# 61-65       67
# 66-70       41
# 71-75       16
# 76-80        9
# Over 80      5
# Name: age_range, dtype: int64

# %%
y_valueslist = values.tolist()

x_valueslist = age_bins[0:-1]

# %%
print(x_valueslist)
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %%
#generate plot of # of incidents per age category#generat 

plt.plot(x_valueslist, y_valueslist, 'ro')
#specify a rotation for the tick labels in degrees or with group_names.
plt.xticks(x_valueslist, group_names, rotation='vertical')
# Pad margins so that markers don't get clipped by the axes
plt.margins(0.2)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.15)

#plot grid & label details
plt.title('# Of OIS Incidents per Age Range')
plt.xlabel('Age Range Categories')
plt.ylabel('Number of Incidents')

plt.grid(True)
plt.savefig("age-bar.png", bbox_inches="tight")

# %%
# %matplotlib notebook

# %%
# Create an array that contains the number of users each language has# Create 
users = [10662, 10797, 10728, 3.4]
x_axis = np.arange(len(users))

# %%
# Tell matplotlib that we will be making a bar chart
# Users is our y axis and x_axis is, of course, our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(x_axis, users, color='r', alpha=0.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 4 artists>

# %%
# Tell matplotlib where we would like to place each of our x axis headers
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["2015", "2016", "2017", "OIS Total"])
# Out:
# ([<matplotlib.axis.XTick at 0x1d770bc3470>,
#   <matplotlib.axis.XTick at 0x1d770bc3748>,
#   <matplotlib.axis.XTick at 0x1d770af0748>,
#   <matplotlib.axis.XTick at 0x1d770b00390>],
#  <a list of 4 Text xticklabel objects>)

# %%
# Sets the x limits of the current chart
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 3.75)

# %%
# Sets the y limits of the current chart# Sets t 
plt.ylim(0, max(users)+5000)
# Out:
# (0, 15797)

# %%
# Give our chart some labels and a tile
plt.title("OIS vs Number of Estimated total Arrests")
plt.xlabel("Year")
plt.ylabel("US Estimated Number of Arrest (in thousands)")
plt.savefig("arrests-bar.png")
